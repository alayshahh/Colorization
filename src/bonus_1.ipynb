# %%
import matplotlib.pyplot as plt
import os
import src.basic_agent_bonus
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-2854e52459b2> in <module>
#       2 import os
#       3 os.listdir()
# ----> 4 import src.basic_agent_bonus
#       5
#       6
#
# ~/Documents/Colorizarion/src/basic_agent_bonus.py in <module>
# ----> 1 import k_means
#       2 from constants import *
#       3 import numpy as np
#       4 from tqdm import tqdm
#       5
#
# ModuleNotFoundError: No module named 'k_means'

# %%
k_means = find_best_k()
# Out:
# 100%|██████████| 49/49 [25:00<00:00, 30.61s/it]

# %%
plt.plot([i for i in range(1,50)], k_means)
plt.xlabel('Number clusters')
plt.ylabel('Distance between actual color and classified color')
plt.title('Finding the best number of clusters')
plt.show()
