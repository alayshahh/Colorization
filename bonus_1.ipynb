# %%
import os
import sys
sys.path.append(os.path.dirname(os.path.abspath('src'))+'/src')
import matplotlib.pyplot as plt
from basic_agent_bonus import find_best_k
import matplotlib.pyplot as plt
from src.basic_agent_bonus import find_best_k

# %%
k_means = find_best_k(100)
# Out:
# 100%|██████████| 99/99 [3:49:47<00:00, 139.27s/it]

# %%
plt.plot([i for i in range(1,100)], k_means)
plt.xlabel('Number clusters k')
plt.ylabel('Loss')
plt.title('Finding the best number of clusters')
plt.show()
